# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
mpl.style.use('ggplot')

# %%
import pandas as pd

# Load the 'quikr_car - quikr_car.csv' dataset into a DataFrame
car = pd.read_csv('/content/sample_data/quikr_car.csv')

# Display the first 5 rows of the DataFrame
display(car.head())
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %% [markdown]
# Imports necessary libraries: pandas for data manipulation, numpy for numerical operations, and matplotlib for plotting.

# %% [markdown]
# Sets the plotting style to 'ggplot' for a visually appealing aesthetic.

# %% [markdown]
# Loads the car data from a CSV file into a pandas DataFrame and displays the first 5 rows.

# %% [markdown]
# Displays the first 5 rows of the `car` DataFrame again.

# %% [markdown]
# Shows the dimensions (number of rows and columns) of the `car` DataFrame.

# %% [markdown]
# Prints a summary of the DataFrame, including data types and non-null values for each column.

# %% [markdown]
# Filters the DataFrame to keep only rows where the 'year' column contains numeric values.

# %% [markdown]
# Converts the 'year' column to integer type.

# %% [markdown]
# Removes rows where the 'Price' column has the value 'Ask For Price'.

# %% [markdown]
# Cleans the 'Price' column by removing commas and converting it to integer type.

# %% [markdown]
# Cleans the 'kms_driven' column by extracting the numeric part and removing commas.

# %% [markdown]
# Filters the DataFrame to keep only rows where the 'kms_driven' column contains numeric values.

# %% [markdown]
# Converts the 'kms_driven' column to integer type.

# %% [markdown]
# Removes rows where the 'fuel_type' column has missing (NaN) values.

# %% [markdown]
# Shows the dimensions (number of rows and columns) of the cleaned `car` DataFrame.

# %% [markdown]
# Extracts the first three words from the 'name' column to standardize car names.

# %% [markdown]
# Resets the DataFrame index after previous filtering operations.

# %% [markdown]
# Displays the entire cleaned `car` DataFrame.

# %% [markdown]
# Saves the cleaned DataFrame to a CSV file named 'Cleaned car data'.

# %% [markdown]
# Generates descriptive statistics for all columns in the DataFrame, including categorical ones.

# %% [markdown]
# Removes rows where the 'Price' column is 'Ask for price' (this was already handled but is a redundant check here).

# %% [markdown]
# Prints a summary of the DataFrame, including data types and non-null values for each column after further cleaning.

# %% [markdown]
# Filters the DataFrame to include only cars with a 'Price' less than 600,000.

# %% [markdown]
# Displays all unique values in the 'company' column.

# %% [markdown]
# Generates a box plot to visualize the distribution of 'Price' for each car 'company', rotating x-axis labels for readability.

# %% [markdown]
# Generates a box plot to visualize the distribution of 'Price' for each 'year', rotating x-axis labels for readability.

# %% [markdown]
# Generates a swarm plot to visualize the distribution of 'Price' for each car 'company', rotating x-axis labels for readability.

# %% [markdown]
# Generates another swarm plot to visualize the distribution of 'Price' for each car 'company', rotating x-axis labels for readability.

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car = car[car['year'].str.isnumeric()]

# %%
car['year'] = car['year'].astype(int)

# %%
car = car[car['Price'] != 'Ask For Price']

# %%
car['Price'] = car['Price'].str.replace(',', '').astype(int)

# %%
car['kms_driven'] = car['kms_driven'].str.split().str.get(0).str.replace(',', '')

# %%
car = car[car['kms_driven'].str.isnumeric()]

# %%
car['kms_driven'] = car['kms_driven'].astype(int)

# %%
car = car[~car['fuel_type'].isna()]

# %%
car.shape
# Out:
# (816, 6)

# %%
car['name'] = car['name'].str.split().str.slice(start=0, stop=3).str.join(' ')

# %%
car = car.reset_index(drop=True)

# %%
car
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 812          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 814            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
car.to_csv("Cleaned car data")

# %%
car.describe(include='all')
# Out:
#                        name company         year         Price     kms_driven  \
# count                   816     816   816.000000  8.160000e+02     816.000000
# unique                  254      25          NaN           NaN            NaN
# top     Maruti Suzuki Swift  Maruti          NaN           NaN            NaN
# freq                     51     221          NaN           NaN            NaN
# mean                    NaN     NaN  2012.444853  4.117176e+05   46275.531863
# std                     NaN     NaN     4.002992  4.751844e+05   34297.428044
# min                     NaN     NaN  1995.000000  3.000000e+04       0.000000
# 25%                     NaN     NaN  2010.000000  1.750000e+05   27000.000000
# 50%                     NaN     NaN  2013.000000  2.999990e+05   41000.000000
# 75%                     NaN     NaN  2015.000000  4.912500e+05   56818.500000
# max                     NaN     NaN  2019.000000  8.500003e+06  400000.000000
#
#        fuel_type
# ...

# %%
car=car[car['Price']!='Ask for price']

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.4+ KB

# %%
car=car[car['Price']<600000]

# %%
car['company'].unique(

)
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi',
#        'Renault', 'Honda', 'Datsun', 'Tata', 'Volkswagen', 'Chevrolet',
#        'Toyota', 'Nissan', 'Hindustan', 'Fiat', 'Force', 'Mercedes',
#        'Mitsubishi'], dtype=object)

# %%
import seaborn as sns
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# /tmp/ipython-input-2207815009.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show(
)
# Out:
# /tmp/ipython-input-487138809.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %%
plt.subplots(figsize=(15,7))
ax=sns.swarmplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show(

)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /tmp/ipython-input-511236435.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.subplots(figsize=(15,7))
ax=sns.swarmplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /tmp/ipython-input-955327338.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
